# %% [markdown]
# # <center>Fake-News-Classifier</center>

# %% [markdown]
# ![Fake-Fact image](https://theleaflet.in/wp-content/uploads/2020/11/190108-fake-thumb.jpg)

# %% [markdown]
# # ♦ Introduction ♦
#
# As of Today, It is very hard to find the difference between the fake and the real news as the social media grows wider.Fake news is false or misleading information presented as news. Fake news often has the aim of damaging the reputation of a person or entity, or making money through advertising revenue.To takle this problem i build a machine learning model which can classify the fake news. It may not be the best model but it is a good model.
#
# #About
# ## Dataset:
# The following dataset used in this project is the famous dataset is taken from the [kaggle](https://www.kaggle.com/datasets/clmentbisaillon/fake-and-real-news-dataset). The dataset contains two csv files named True.csv and Fake.csv which consists of the real news and fake news respectively. Each csv file contains 4 attributes.
#
# **The Attributes of the Dataset**:
# 1. Title:
#          Title of the News, containing 17903 unique values
# 2. Text:
#          Text Attribute consists of the news written/published in the articles.
# 3. Subject:
#           The Subject Attribute contains the type of news like Political News, World News or just the regular news.
# 4. Date:
#           The date attribute contains the date that this article was posted at.
#
#
#
# ## Project:
# The project **Fake News Classifier** is a part of Big Data  Course Project.This Project is completed under Dr.Kanishka Tyagi.In this Project, I made a model analysis so that anyone can choose the best model according to the accuracy of that model to classify the Fake News.In this Project I used  **Bag of Words** method and **Multinomial Naive Bayes** Classifier for the Model Training

# %% [markdown]
# ## The Model is trained on the basis of 'Text of the Article' in the Dataset

# %% [markdown]
# lets install all the required libraries to download the dataset

# %%
# !pip install pandas opendatasets --upgrade --quiet

# %%
import pandas as pd
import opendatasets as opd

# %% [markdown]
# ## Download
#
# There are several ways to download the dataset and upload it into your jupyter notebook.
# Here is one of the method I am using in this project:
# 1. Install the [opendatasets](https://github.com/JovianML/opendatasets#opendatasets) library into your Notebook.
# 2. Copy the URL of the dataset and save the URL into a variable.
# 3. Use the 'download' function to download the csv file of the dataset.
# 4. Now you can insert the csv file to your jupyter notebook and perform several operations.

# %% [markdown]
# Through this process you may asked to enter the username and API key of Kaggle Account, You need to input those values to proceed Downloading.In case it is already Installed, it does not required
#
# Create an API key in Kaggle.
#
# Step 1:  To do this, go to kaggle.com/ and open your user settings page.
# ![image1](https://i.stack.imgur.com/jxGQv.png)
#
# Step 2:Next, scroll down to the API access section and click generate to download an API key.
# ![image2](https://i.stack.imgur.com/Hzlhp.png)
# This will download a file called kaggle.json to your computer. You'll use this file in Jupyter Notebook/Google Colab to access Kaggle datasets and competitions.

# %%
opd.download('https://www.kaggle.com/datasets/clmentbisaillon/fake-and-real-news-dataset')
# Out:
# Skipping, found downloaded files in ".\fake-and-real-news-dataset" (use force=True to force download)

# %% [markdown]
# The dataset thas been downloadeed and extracted

# %%
# !pip install os --upgrade --quiet
import os
os.listdir('./fake-and-real-news-dataset')
# Out:
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
# ERROR: No matching distribution found for os
# ['Fake.csv', 'True.csv']

# %% [markdown]
# The Dataset containd two CSV files 'True.csv' and 'Fake.csv'

# %% [markdown]
# # Data Preperation and Cleaning
# Lets Load the File 'Fake.csv' into pandas dataframe and perform some cleaning if required.

# %%
fake_df = pd.read_csv('./fake-and-real-news-dataset/Fake.csv',index_col = False)

# %%
fake_df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %% [markdown]
# **.columns()** method give the list of all the attributes presented in the dataset.

# %%
fake_df.columns
# Out:
# Index(['title', 'text', 'subject', 'date'], dtype='object')

# %% [markdown]
# **.count()** method provides the Total Number of values present in the Dataset

# %%
fake_df.count()
# Out:
# title      23481
# text       23481
# subject    23481
# date       23481
# dtype: int64

# %% [markdown]
# ### Checking if there any NULL values present in the Fake Dataframe

# %% [markdown]
# **.info()** provides all the information regarding the attributes in the dataset.

# %%
fake_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23481 entries, 0 to 23480
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    23481 non-null  object
#  1   text     23481 non-null  object
#  2   subject  23481 non-null  object
#  3   date     23481 non-null  object
# dtypes: object(4)
# memory usage: 733.9+ KB

# %% [markdown]
# As there are no NULL values in the datset. let's move on to the next step.

# %%
fake_df.memory_usage(deep = True)
# Out:
# Index           128
# title       5380518
# text       61153828
# subject     1507065
# date        1646426
# dtype: int64

# %% [markdown]
# As we are only preparing model using 'text' attribute in the dataset, Here seperating the 'text' column from the dataframe and aperform some operations

# %%
df_f = fake_df.loc[ : ,['text']]

# %%
df_f.head(5)
# Out:
#                                                 text
# 0  Donald Trump just couldn t wish all Americans ...
# 1  House Intelligence Committee Chairman Devin Nu...
# 2  On Friday, it was revealed that former Milwauk...
# 3  On Christmas day, Donald Trump announced that ...
# 4  Pope Francis used his annual Christmas Day mes...

# %% [markdown]
# ### Checking for the Duplicate Values in the Fake Dataframe

# %%
df_f.count()
# Out:
# text    23481
# dtype: int64

# %% [markdown]
# Here the Total number of values in the dataset is **23481**

# %% [markdown]
# Finding out the total number of unique values in the dataset

# %%
n = len(pd.unique(df_f['text']))
print(n)
# Out:
# 17455

# %% [markdown]
# Here the Total Number of Unique Values are **17455** , Remaining **6026** isn't useful for training the model so let's delete them from the dataset

# %%
df_f.drop_duplicates(inplace=True)

# %%
df_f.count()
# Out:
# text    17455
# dtype: int64

# %% [markdown]
# Now, The Duplicate values has been removed from the dataset.

# %%
df_f.head(5)
# Out:
#                                                 text
# 0  Donald Trump just couldn t wish all Americans ...
# 1  House Intelligence Committee Chairman Devin Nu...
# 2  On Friday, it was revealed that former Milwauk...
# 3  On Christmas day, Donald Trump announced that ...
# 4  Pope Francis used his annual Christmas Day mes...

# %% [markdown]
# Adding a new column named **TorF** to the dataset to identify wheather the news is Fake or True. For this dataset every value is assigned as 0 as every news is Fake.

# %%
df_f['TorF'] = 0

# %%
df_f.head(5)
# Out:
#                                                 text  TorF
# 0  Donald Trump just couldn t wish all Americans ...     0
# 1  House Intelligence Committee Chairman Devin Nu...     0
# 2  On Friday, it was revealed that former Milwauk...     0
# 3  On Christmas day, Donald Trump announced that ...     0
# 4  Pope Francis used his annual Christmas Day mes...     0

# %% [markdown]
# Shuffling the Fake Dataframe

# %%
df_f = df_f.sample(frac=1).reset_index(drop=True)

# %%
df_f.head(10)
# Out:
#                                                 text  TorF
# 0  Donald Trump has repeatedly defended his blata...     0
# 1   Every record has been destroyed or falsified,...     0
# 2  Hillary pandering to the Black Lives Matter cr...     0
# 3  Saturday Night Live s cold open last night was...     0
# 4  Project Veritas  newest video from the America...     0
# 5  If you had any doubt in your mind that Republi...     0
# 6  President Trump and First Lady Melania Trump m...     0
# 7  Trump is a millionaire who clearly doesn t nee...     0
# 8  A customer at a New Orleans Family Dollar stor...     0
# 9  THE NUMBER OF AMERICANS ON FOOD STAMPS IS AT A...     0

# %% [markdown]
# ### Performing the Similar Operations on the True News Dataset

# %% [markdown]
# Converting **True.csv** into Pandas Dataframe

# %%
True_df = pd.read_csv('./fake-and-real-news-dataset/True.csv',index_col = False)

# %%
True_df.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
True_df.columns
# Out:
# Index(['title', 'text', 'subject', 'date'], dtype='object')

# %%
True_df.count()
# Out:
# title      21417
# text       21417
# subject    21417
# date       21417
# dtype: int64

# %%
True_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21417 entries, 0 to 21416
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    21417 non-null  object
#  1   text     21417 non-null  object
#  2   subject  21417 non-null  object
#  3   date     21417 non-null  object
# dtypes: object(4)
# memory usage: 669.4+ KB

# %%
True_df.describe()
# Out:
#                                                     title  \
# count                                               21417
# unique                                              20826
# top     Factbox: Trump fills top jobs for his administ...
# freq                                                   14
#
#                                                      text       subject  \
# count                                               21417         21417
# unique                                              21192             2
# top     (Reuters) - Highlights for U.S. President Dona...  politicsNews
# freq                                                    8         11272
#
#                       date
# count                21417
# unique                 716
# top     December 20, 2017
# freq                   182

# %%
True_df.memory_usage(deep = True)
# Out:
# Index           128
# title       2609581
# text       81025844
# subject     1447338
# date        1578819
# dtype: int64

# %% [markdown]
# Extracting the **text** attribute from the dataset and perform data cleaning

# %%
df_t = True_df.loc[ : ,['text']]

# %%
df_t.head(5)
# Out:
#                                                 text
# 0  WASHINGTON (Reuters) - The head of a conservat...
# 1  WASHINGTON (Reuters) - Transgender people will...
# 2  WASHINGTON (Reuters) - The special counsel inv...
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...

# %% [markdown]
# ### Finding out the Total number of duplicate values in the True datsframe

# %%
df_t.count()
# Out:
# text    21417
# dtype: int64

# %% [markdown]
# The Total Number of values in the True Dataframe are **21417**

# %% [markdown]
# Finding out the Total Number of Unique Values in the True Dataframe

# %%
n = len(pd.unique(df_t['text']))
print(n)
# Out:
# 21192

# %% [markdown]
# There are **21192** unique values in the True Dataframe. So, there are 225 duplicate values in the dataframe.

# %% [markdown]
# Removing the Duplicate Values in the Dataframe

# %%
df_t.drop_duplicates(inplace=True)

# %%
df_t.count()
# Out:
# text    21192
# dtype: int64

# %%
df_t.head()
# Out:
#                                                 text
# 0  WASHINGTON (Reuters) - The head of a conservat...
# 1  WASHINGTON (Reuters) - Transgender people will...
# 2  WASHINGTON (Reuters) - The special counsel inv...
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...

# %% [markdown]
# Adding a new column **TorF** to differentiate the fake news .

# %%
df_t['TorF'] = 1

# %% [markdown]
# Here all the values are assigned **1** beacuse the present dataset contains all the true news.

# %%
df_t.head()
# Out:
#                                                 text  TorF
# 0  WASHINGTON (Reuters) - The head of a conservat...     1
# 1  WASHINGTON (Reuters) - Transgender people will...     1
# 2  WASHINGTON (Reuters) - The special counsel inv...     1
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...     1
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...     1

# %% [markdown]
# Shuffling the Dataframe

# %%
df_t = df_t.sample(frac=1).reset_index(drop=True)

# %%
df_t.head(10)
# Out:
#                                                 text  TorF
# 0  SHAMLAPUR, Bangladesh/DHAKA (Reuters) - Myanma...     1
# 1  MOSCOW (Reuters) - The Paris climate deal is u...     1
# 2  WASHINGTON (Reuters) - President Donald Trump ...     1
# 3  BERLIN (Reuters) - Swept into parliament by th...     1
# 4  NEW YORK (Reuters) - Billionaire activist inve...     1
# 5  (Reuters) - The continuing controversy over fo...     1
# 6  WASHINGTON (Reuters) - The U.S. failure to ret...     1
# 7  SEOUL (Reuters) - U.S. President Donald Trump’...     1
# 8  DUBLIN (Reuters) - The best way to avoid the r...     1
# 9  BOSTON (Reuters) - (Editor’s note: This story ...     1

# %% [markdown]
# ### Combining the two dataframe into one dataframe

# %%
df_combined = pd.concat([df_f,df_t])

# %%
df_combined
# Out:
#                                                     text  TorF
# 0      Donald Trump has repeatedly defended his blata...     0
# 1       Every record has been destroyed or falsified,...     0
# 2      Hillary pandering to the Black Lives Matter cr...     0
# 3      Saturday Night Live s cold open last night was...     0
# 4      Project Veritas  newest video from the America...     0
# ...                                                  ...   ...
# 21187  MOSCOW (Reuters) - A Russian media group which...     1
# 21188  MANILA (Reuters) - Most Filipinos believe only...     1
# 21189  BEIJING (Reuters) - China is focused on solvin...     1
# 21190  (Reuters) - The American Civil Liberties Union...     1
# 21191  WASHINGTON (Reuters) - Former U.S. President B...     1
#
# [38647 rows x 2 columns]

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38647 entries, 0 to 21191
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    38647 non-null  object
#  1   TorF    38647 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 905.8+ KB

# %% [markdown]
# Shuffling the Combined Dataframe

# %%
df_combined = df_combined.sample(frac=1).reset_index(drop=True)

# %%
df_combined.head(10)
# Out:
#                                                 text  TorF
# 0  BEDMINSTER, N.J. (Reuters) - U.S. President Do...     1
# 1  Russia gave John Podesta 35 millions dollars (...     0
# 2  Fox Host Bret Baier found himself forced to re...     0
# 3  Secretary of State Rex Tillerson just shut dow...     0
# 4  Will Megyn Kelly be working towards a  gotcha ...     0
# 5  Following the situation in Charlottesville, Tr...     0
# 6  They re calling them  Y all Qaeda.  It s all a...     0
# 7  Donald Trump said Monday that Japan s SoftBank...     0
# 8  Senator Kelly Ayotte (R-NH) is fighting hard t...     0
# 9  The author of  Clinton Cash  responds to Hilla...     0

# %% [markdown]
# # Data pre-processing

# %% [markdown]
# The NLP methods using in this Project:
# 1. Using regular expression, Removing punctuations,special characters and replacing them with spaces abd converting the whole dataframe into lowercase words.
# 2. Applying Stemming on the whole Dataframe
# 3. Removing the English Stopwords

# %% [markdown]
# The **NLTK** library consists of many useful NLP methods , which we use in this project.

# %% [markdown]
# Installing the necessary libraries

# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

# %% [markdown]
# Creating the Object of PorterStemmer() for Stemming.

# %%
ps = PorterStemmer()
corpus = []

# %% [markdown]
# Iterating each row and applying the regular expressions,removing stopwords and stemming and combining to make a list of sentences.

# %%
from  tqdm import tqdm_notebook as tqdm
for i in tqdm(range(0, len(df_combined))):
    review = re.sub('[^a-zA-Z]' , ' ',df_combined['text'][i])
    review = review.lower()
    review = review.split()
    
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    corpus.append(review)
# Out:
# C:\Users\rohan\AppData\Local\Temp/ipykernel_14844/3736447135.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm(range(0, len(df_combined))):
#   0%|          | 0/38647 [00:00<?, ?it/s]

# %% [markdown]
# Corpus returns a list of all the sentences that are ready to be trained.

# %%
corpus
# Out:
# ['bedminst n j reuter u presid donald trump thursday declar opioid epidem nation emerg said administr draft paper make offici opioid crisi emerg say offici right emerg trump told report new jersey go draw go make nation emerg seriou problem like never trump spoke week white hous commiss opioid crisi led new jersey governor chri christi recommend presid declar nation emerg declar could help unlock support resourc address drug overdos epidem addit fund expand access variou form treatment give govern flexibl waiv rule restrict expedit action nation emerg typic declar short term crise zika viru outbreak natur disast unclear trump declar mean complex long term public health problem go spend lot time lot effort lot money opioid crisi trump said worldwid problem unit state problem american die drug overdos everi day commiss wrote report note america endur death toll equal septemb th everi three week opioid play role death accord u center diseas control prevent trump held major brief epidem tuesday stop short follow commiss recommend instead talk mostli stop flow drug unit state ensur young peopl never start use drug discuss access treatment',
#  'russia gave john podesta million dollar billion rubl advis hillari clinton barack obama pic twitter com cf xzleu base vet basedvet march',
#  'fox host bret baier found forc retract statement earlier today claim indict hillari clinton like well pretti much lie promptli got caught fbi siev inform hillari late baier supposedli got inform time ask one fbi agent spoke guardian condit anonym might part answer fact destroy bureau reput truth bomb actual happen accord agent fbi basic trumplandia agenc anyth like object investig hillari current serv fbi agent said clinton antichrist personifi larg swath fbi personnel reason leak pro trump appar attitud got wors director jame comey decid recommend indict hillari earlier year lot trumpkin countri angri like woman clear present threat chosen candid witch hunt littl actual evid crimin trumpkin stand whether trumpkin mani fbi unfavor view hillari rais seriou question agenc integr right lot peopl think trump qualifi also believ clinton corrupt hear lot bad choic incompet corrupt politician bureau come fire handl investig along comey decis send letter congress newli discov email day elect alon enough give impress object especi sinc comey refus respond critic daili beast also pick stori alleg connect rudi giuliani got head buri deep insid trump ass new york citi fbi offic offic press headquart continu look matter hillari email comey declar investig effect close agent piss comey believ failur recommend indict shook peopl faith bureau leak bureau continu pretti clear fbi fact witch hunt hillari rather conduct legitim investig legitim problem anyth call fbi integr question rather comey decis indict back juli imag hillari clinton justin sullivan imag jame comey alex wong via getti imag',
#  'secretari state rex tillerson shut obnoxi press respond rumor tension presid donald trump report white hous plan push posit tell report need get new sourc boom tillerson nonsens style hit report right eye tillerson comment came press confer nato headquart brussel associ press report josh lederman ask nation top diplomat quit amid multipl report cite trump administr offici white hous develop plan oust tillerson replac cia director mike pompeo turn would replac republican sen tom cotton ark sever occas presid publicli undermin diplomat effort lederman said recent day white hous offici said go push media invent come white hous mani american see effort humili lederman continu illustri career put quit press keep push get answer tillerson rumor leav trump administr januari problem report ask ask ask rude',
#  'washington reuter u democrat senat al franken return congress monday begin call process rebuild trust shatter alleg grope inappropri touch women vow happen know go much consciou circumst much care much sensit happen go forward told report outsid offic capitol hill franken accus sexual misconduct leann tweeden radio broadcast appear franken entertain tour u troop serv war zone prior win senat seat franken well known comedian televis writer author anoth woman lindsay menz accus franken touch buttock photograph minnesota state fair contrit franken appear monday throng report gather outsid offic senat vow get back work follow week long senat thanksgiv break know magic word say regain trust know go take time readi start process start go back work today franken said appar address minnesota constitu back home franken first elect due run third senat term follow sexual misconduct alleg movi produc harvey weinstein addit complaint made regard big name entertain polit notabl republican u senat candid roy moor alabama repres john conyer michigan three men deni alleg reuter abl verifi conyer step senior democrat hous repres judiciari committe novemb franken bare elect race close took vote recount court rule final declar winner follow juli close race background entertain govern servic franken came senat refus media interview kept low profil tri demonstr constitu seriou new polit career eight year later franken prove minnesotan note support count champion women franken apolog behavior respons report question said would open make public find senat ethic probe process complet',
#  'report expos email share wikileak show result review complet jennif reynoso new york lawyer report state clinton foundat miss sever polici procedur requir law e g record retent polici report goe give follow recommend addit point employe clinton foundat underpaid compar compar posit compani email also state overal moral compani low staff would like see structur staff moral low staff hungri structureiron staff complain polici made avail employe blow whistl potenti wrongdo within non profit given bill clinton histori sexual predat role clinton foundat come surpris strong sexual harass polici place',
#  'washington reuter michael flynn former nation secur advis presid donald trump prepar testifi trump direct make contact russian presidenti candid abc news report friday reuter verifi abc news report cite flynn confid',
#  'berlin reuter german govern condemn tuesday fire ballist missil houthi militia toward riyadh call immedi ceasefir u n led peac negoti condemn renew missil launch yemen capit kingdom saudi arabia strongest term foreign ministri spokesman said justif act missil attack saudi arabia must final stop spokesman said yemen conflict could solv diplomat mean urg parti adopt immedi ceasefir negoti aegi unit nation',
#  ...]

# %% [markdown]
# # Bag of Words
#
# The bag-of-words (BOW) model is a representation that turns arbitrary text into fixed-length vectors by counting how many times each word appears. This process is often referred to as vectorization.
#
# ## How is BOW useful?
# Despite being a relatively basic model, BOW is often used for Natural Language Processing (NLP) tasks like Text Classification. Its strengths lie in its simplicity: it’s inexpensive to compute, and sometimes simpler is better when positioning or contextual info aren’t relevant.

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features = 7000)
X = cv.fit_transform(corpus).toarray()

# %%
Y = df_combined.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size = 0.20 , random_state = 0)

# %%
from sklearn.naive_bayes import MultinomialNB
fake_news_model = MultinomialNB().fit(X_train,Y_train)

# %%
Y_pred = fake_news_model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
matrix = confusion_matrix(Y_test,Y_pred)
matrix
# Out:
# array([[3295,  190],
#        [ 218, 4027]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(Y_test,Y_pred)
accuracy
# Out:
# 0.9472186287192755

# %% [markdown]
# Here, We got an accuracy of `94.7`%.This may change because using Random Sampling the highest accuracy i got was `95.5`%, Don't Worry it won't be much Different.

# %% [markdown]
# ## Saving The Model
# Saving Machine Learning Model using joblib.

# %%
# !pip install joblib --upgrade --quiet
import joblib
filename1 = 'BOW_model.sav'
joblib.dump(fake_news_model, filename1)
# Out:
# ['BOW_model.sav']

# %% [markdown]
# ### To load the data:
#
# loaded_model = joblib.load(filename1)
